# %% [markdown]
# # ERA Interim Download

# %% [markdown]
# This notebook contains the code to download the climatology data upon which the retrieval is based.
#
# ## Profiles

# %%
#!/usr/bin/env python
from ecmwfapi import ECMWFDataServer
server = ECMWFDataServer()
server.retrieve({
    "class": "ei",
    "dataset": "interim",
    "date": "2016-04-01/to/2016-09-31",
    "expver": "1",
    "grid": "2.0/2.0",
    "levelist": "100/125/150/175/200/225/250/300/350/400/450/500/550/600/650/700/750/775/800/825/850/875/900/925/950/975/1000",
    "levtype": "pl",
    "param": "130.128/131.128/132.128/133.128/203.128",
    "area": "23.0/-180.0/66.0/180.0",
    "format": "netcdf",
    "step": "0",
    "stream": "oper",
    "time": "00:00:00/06:00:00/12:00:00/18:00:00",
    "type": "an",
    "target": "data/era_interim_mid_latitudes_2016_summer.hdf5",
})
# Out:
# 2017-11-12 17:08:34 ECMWF API python library 1.5.0
# 2017-11-12 17:08:34 ECMWF API at https://api.ecmwf.int/v1
# 2017-11-12 17:08:34 Welcome Simon Pfreundschuh
# 2017-11-12 17:08:35 In case of problems, please check https://software.ecmwf.int/wiki/display/WEBAPI/Troubleshooting or contact calldesk@ecmwf.int
# 2017-11-12 17:08:35
# 2017-11-12 17:08:35 Request submitted
# 2017-11-12 17:08:35 Request id: 5a08723bde6efe8c76ecc12e
# 2017-11-12 17:08:35 Request is queued
# Calling '['nice', 'mars', '/tmp/tmp-_marsbE13ag.req']'
# mars - WARN -
# mars - WARN - From 9 February 2016 10AM (UTC) MARS uses versions of
# mars - WARN - libemos newer than 4.3.0. For more details, see
# mars - WARN - https://software.ecmwf.int/wiki/display/EMOS/Bug+fix+implemented+in+EMOSLIB+4.3.x
# mars - WARN -
# PPDIR is /var/tmp/ppdir/x86_64
# mars - INFO   - 20171112.160941 - Welcome to MARS with ecCodes + ODB
# mars - INFO   - 20171112.160941 - MARS Client build stamp: 20170719164934
# ...

# %% [markdown]
# ## Scalar Variables

# %%
server.retrieve({
    "class": "ei",
    "dataset": "interim",
    "date": "2016-04-01/to/2016-09-31",
    "expver": "1",
    "grid": "2.0/2.0",
    "levtype": "sfc",
    "param": "34.128/137.128",
    "area": "23.0/-180.0/66.0/180.0",
    "format": "netcdf",
    "step": "0",
    "stream": "oper",
    "time": "00:00:00/06:00:00/12:00:00/18:00:00",
    "type": "an",
    "target": "data/era_interim_mid_latitudes_2016_summer_sst_cwv.nc"
})
# Out:
# 2017-11-12 18:25:28 ECMWF API python library 1.5.0
# 2017-11-12 18:25:28 ECMWF API at https://api.ecmwf.int/v1
# 2017-11-12 18:25:29 Welcome Simon Pfreundschuh
# 2017-11-12 18:25:29 In case of problems, please check https://software.ecmwf.int/wiki/display/WEBAPI/Troubleshooting or contact calldesk@ecmwf.int
# 2017-11-12 18:25:29
# 2017-11-12 18:25:29 Request submitted
# 2017-11-12 18:25:29 Request id: 5a08844212b438018a2422c9
# 2017-11-12 18:25:29 Request is queued
# Calling '['nice', 'mars', '/tmp/tmp-_marsIPgR3a.req']'
# mars - WARN -
# mars - WARN - From 9 February 2016 10AM (UTC) MARS uses versions of
# mars - WARN - libemos newer than 4.3.0. For more details, see
# mars - WARN - https://software.ecmwf.int/wiki/display/EMOS/Bug+fix+implemented+in+EMOSLIB+4.3.x
# mars - WARN -
# PPDIR is /var/tmp/ppdir/x86_64
# mars - INFO   - 20171112.172639 - Welcome to MARS with ecCodes + ODB
# mars - INFO   - 20171112.172639 - MARS Client build stamp: 20170719164934
# ...
